# %%
#if you're using jupyter notebook, use the following line before anything else to show plots on the page
# %matplotlib notebook

#Uncomment following for a pop-out window with more control over plots. You must reset kernel if you change
#%matplotlib qt5

#most data projects start with importing these modules
import pandas as pd    #gets you dataframes and many tools
import numpy as np     #get you math constants, matrix math, and other things
import matplotlib.pyplot as plt    #gets you plotting functions

# %% [markdown]
# ### Example using just matplotlib

# %%
sample_x = [1,2,3,4,5]
sample_y = [34,65,23,78,43]

# all figures should start with the next two lines
fig = plt.figure()    #creates an empty figure
ax = fig.add_subplot(111)  #creates axes on the figure. 111 = 1 vertical axis, 1 horiz axis, following should edit first plot
ax1 = ax.plot(sample_x,sample_y,label="my data") #ax.plot(xdata,ydata,optional properties....)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
#personalize the plot
ax.set_title('hi')
ax.set_ylabel('y-axis')
ax.set_xlabel('x-axis')
ax.grid()
ax.legend()

#in Jupyter notebook...it will keep updating the plot that printed first, until you make a new fig

# %% [markdown]
# Try playing with the plt.plot() properties.
# A full list of properties is here: https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html
#
# Try something like the following:
# plt.plot([xdata],[ydata],linewidth=3,color='green',marker='v',label="first series")
#
# You can literally make any line style you can think of. It may take some testing to figure out what you like, but then it is set.
